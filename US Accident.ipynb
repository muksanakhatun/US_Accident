# %% [markdown]
# ## US-accidents

# %% [markdown]
# Download the dataset on accidents in the US here:
# https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents.
#
# Data description
# https://smoosavi.org/datasets/us_accidents

# %% [markdown]
# Done by- **Wurdruw Zurovast & Muksana Khatun**
#
#
# Date-23/10/2022

# %% [markdown]
# #### 0. Load packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# #### 1. Load and inspect the data

# %%
accidents = pd.read_csv('US_Accidents_Dec21_updated.csv')

# %%
accidents.head(5)
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# 2                   At I-71/US-50/Exit 1 - Accident.  ...       False   False
# 3                    At Dart Ave/Exit 21 - Accident.  ...       False   False
# 4                 At Mitchell Ave/Exit 6 - Accident.  ...       False   False
#
#     Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0  False           False          False        False          Night
# 1  False           False          False        False          Night
# 2  False           False          False        False          Night
# 3  False           False          False        False          Night
# 4  False           False          False        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                 Night
# 2          Night             Night                   Day
# 3          Night               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 47 columns]

# %%
accidents.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06
# mean   2.137572e+00  3.624520e+01 -9.711463e+01  3.624532e+01 -9.711439e+01
# std    4.787216e-01  5.363797e+00  1.831782e+01  5.363873e+00  1.831763e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.344517e+01 -1.180331e+02  3.344628e+01 -1.180333e+02
# 50%    2.000000e+00  3.609861e+01 -9.241808e+01  3.609799e+01 -9.241772e+01
# 75%    2.000000e+00  4.016024e+01 -8.037243e+01  4.016105e+01 -8.037338e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.845342e+06  1.101431e+06    2.776068e+06   2.375699e+06
# mean   7.026779e-01  8.089408e+03    6.179356e+01   5.965823e+01
# std    1.560361e+00  1.836009e+04    1.862263e+01   2.116097e+01
# min    0.000000e+00  0.000000e+00   -8.900000e+01  -8.900000e+01
# 25%    5.200000e-02  1.270000e+03    5.000000e+01   4.600000e+01
# 50%    2.440000e-01  4.007000e+03    6.400000e+01   6.300000e+01
# 75%    7.640000e-01  9.567000e+03    7.600000e+01   7.600000e+01
# max    1.551860e+02  9.999997e+06    1.960000e+02   1.960000e+02
#
#         Humidity(%)  Pressure(in)  Visibility(mi)  Wind_Speed(mph)  \
# count  2.772250e+06  2.786142e+06    2.774796e+06     2.687398e+06
# mean   6.436545e+01  2.947234e+01    9.099391e+00     7.395044e+00
# std    2.287457e+01  1.045286e+00    2.717546e+00     5.527454e+00
# min    1.000000e+00  0.000000e+00    0.000000e+00     0.000000e+00
# 25%    4.800000e+01  2.931000e+01    1.000000e+01     3.500000e+00
# 50%    6.700000e+01  2.982000e+01    1.000000e+01     7.000000e+00
# 75%    8.300000e+01  3.001000e+01    1.000000e+01     1.000000e+01
# max    1.000000e+02  5.890000e+01    1.400000e+02     1.087000e+03
#
#        Precipitation(in)
# count       2.295884e+06
# mean        7.016940e-03
# std         9.348831e-02
# min         0.000000e+00
# 25%         0.000000e+00
# 50%         0.000000e+00
# 75%         0.000000e+00
# max         2.400000e+01

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
#  21  Temperature(F)         float64
#  22  Wind_Chill(F)          float64
#  23  Humidity(%)            float64
#  24  Pressure(in)           float64
#  25  Visibility(mi)         float64
#  26  Wind_Direction         object
#  27  Wind_Speed(mph)        float64
#  28  Precipitation(in)      float64
#  29  Weather_Condition      object
#  30  Amenity                bool
#  31  Bump                   bool
#  32  Crossing               bool
#  33  Give_Way               bool
#  34  Junction               bool
#  35  No_Exit                bool
#  36  Railway                bool
#  37  Roundabout             bool
#  38  Station                bool
#  39  Stop                   bool
#  40  Traffic_Calming        bool
#  41  Traffic_Signal         bool
#  42  Turning_Loop           bool
#  43  Sunrise_Sunset         object
#  44  Civil_Twilight         object
#  45  Nautical_Twilight      object
#  46  Astronomical_Twilight  object
# dtypes: bool(13), float64(13), int64(1), object(20)
# memory usage: 773.4+ MB

# %%
plt.figure(figsize=(17, 15))
heatmap = sns.heatmap(accidents.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap')
plt.show()

# %%
accidents.corr()['Severity'].sort_values()
# Out:
# Wind_Chill(F)       -0.097459
# Temperature(F)      -0.045335
# Crossing            -0.035382
# Station             -0.018017
# Traffic_Signal      -0.012798
# Amenity             -0.003940
# Bump                -0.003739
# Traffic_Calming     -0.003009
# Stop                -0.002536
# No_Exit             -0.002359
# Railway             -0.001747
# Roundabout          -0.000773
# Number              -0.000689
# Visibility(mi)       0.007371
# Give_Way             0.008141
# Precipitation(in)    0.013845
# Humidity(%)          0.037802
# Pressure(in)         0.043883
# Junction             0.045928
# Wind_Speed(mph)      0.048382
# Start_Lat            0.089207
# End_Lat              0.089209
# Distance(mi)         0.092140
# Start_Lng            0.114063
# End_Lng              0.114064
# Severity             1.000000
# Turning_Loop              NaN
# Name: Severity, dtype: float64

# %% [markdown]
# #### 2. Data cleaning and manipulation

# %%
accidents.isnull().sum(axis = 0)
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                        0
# End_Lng                        0
# Distance(mi)                   0
# Description                    0
# Number                   1743911
# Street                         2
# Side                           0
# City                         137
# County                         0
# State                          0
# Zipcode                     1319
# Country                        0
# Timezone                    3659
# Airport_Code                9549
# Weather_Timestamp          50736
# Temperature(F)             69274
# Wind_Chill(F)             469643
# Humidity(%)                73092
# Pressure(in)               59200
# Visibility(mi)             70546
# Wind_Direction             73775
# Wind_Speed(mph)           157944
# Precipitation(in)         549458
# Weather_Condition          70636
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset              2867
# Civil_Twilight              2867
# Nautical_Twilight           2867
# Astronomical_Twilight       2867
# dtype: int64

# %%
round(accidents.isnull().sum() / accidents.shape[0] * 100.00,2)
# Out:
# ID                        0.00
# Severity                  0.00
# Start_Time                0.00
# End_Time                  0.00
# Start_Lat                 0.00
# Start_Lng                 0.00
# End_Lat                   0.00
# End_Lng                   0.00
# Distance(mi)              0.00
# Description               0.00
# Number                   61.29
# Street                    0.00
# Side                      0.00
# City                      0.00
# County                    0.00
# State                     0.00
# Zipcode                   0.05
# Country                   0.00
# Timezone                  0.13
# Airport_Code              0.34
# Weather_Timestamp         1.78
# Temperature(F)            2.43
# Wind_Chill(F)            16.51
# Humidity(%)               2.57
# Pressure(in)              2.08
# Visibility(mi)            2.48
# Wind_Direction            2.59
# Wind_Speed(mph)           5.55
# Precipitation(in)        19.31
# Weather_Condition         2.48
# Amenity                   0.00
# Bump                      0.00
# Crossing                  0.00
# Give_Way                  0.00
# Junction                  0.00
# No_Exit                   0.00
# Railway                   0.00
# Roundabout                0.00
# Station                   0.00
# Stop                      0.00
# Traffic_Calming           0.00
# Traffic_Signal            0.00
# Turning_Loop              0.00
# Sunrise_Sunset            0.10
# Civil_Twilight            0.10
# Nautical_Twilight         0.10
# Astronomical_Twilight     0.10
# dtype: float64

# %%
null_accidents = pd.DataFrame((accidents.isnull().sum())*100/accidents.shape[0]).reset_index()
null_accidents.columns = ['Column Name', 'Null Values Percentage']

# %%
fig = plt.figure(figsize=(15,6))
ax = sns.pointplot(x="Column Name",y="Null Values Percentage",
                   data=null_accidents,color='blue')
sns.set_theme(style="darkgrid")
plt.xticks(rotation =90,fontsize =7)
ax.axhline(20, ls='--',color='red')
plt.title("Percentage of Missing values in application data")
plt.ylabel("Null Values PERCENTAGE")
plt.xlabel("COLUMNS")
plt.show()

# %%
nullcol_20_accident = null_accidents[null_accidents["Null Values Percentage"]>=20]
nullcol_20_accident
# Out:
#    Column Name  Null Values Percentage
# 10      Number               61.290031

# %% [markdown]
# ### 3.Analysis

# %%
sns.histplot(data=accidents, x='Severity')
plt.show()

# %%
accidents.Severity.value_counts()
# Out:
# 2    2532991
# 3     155105
# 4     131193
# 1      26053
# Name: Severity, dtype: int64

# %%
sev_2 = accidents.loc[accidents["Severity"] == 2]

# %%
sev_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2532991 entries, 1 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
#  21  Temperature(F)         float64
#  22  Wind_Chill(F)          float64
#  23  Humidity(%)            float64
#  24  Pressure(in)           float64
#  25  Visibility(mi)         float64
#  26  Wind_Direction         object
#  27  Wind_Speed(mph)        float64
#  28  Precipitation(in)      float64
#  29  Weather_Condition      object
#  30  Amenity                bool
#  31  Bump                   bool
#  32  Crossing               bool
#  33  Give_Way               bool
#  34  Junction               bool
#  35  No_Exit                bool
#  36  Railway                bool
#  37  Roundabout             bool
#  38  Station                bool
#  39  Stop                   bool
#  40  Traffic_Calming        bool
#  41  Traffic_Signal         bool
#  42  Turning_Loop           bool
#  43  Sunrise_Sunset         object
#  44  Civil_Twilight         object
#  45  Nautical_Twilight      object
#  46  Astronomical_Twilight  object
# dtypes: bool(13), float64(13), int64(1), object(20)
# memory usage: 707.8+ MB

# %%
# 2,532,991 Severity 2 accidents.
sev_2.nunique()# 2,532,991 Severity 2 accidents.
sev_2.nunique()
# Out:
# ID                       2532991
# Severity                       1
# Start_Time               1725455
# End_Time                 2107597
# Start_Lat                 987383
# Start_Lng                1008048
# End_Lat                   973756
# End_Lng                   992367
# Distance(mi)               12743
# Description              1044802
# Number                     44698
# Street                    148503
# Side                           3
# City                       10481
# County                      1594
# State                         49
# Zipcode                   328923
# Country                        1
# Timezone                       4
# Airport_Code                1930
# Weather_Timestamp         409191
# Temperature(F)               743
# Wind_Chill(F)                833
# Humidity(%)                  100
# Pressure(in)                1048
# Visibility(mi)                73
# Wind_Direction                24
# Wind_Speed(mph)              126
# Precipitation(in)            222
# Weather_Condition            121
# Amenity                        2
# Bump                           2
# Crossing                       2
# Give_Way                       2
# Junction                       2
# No_Exit                        2
# Railway                        2
# Roundabout                     2
# Station                        2
# Stop                           2
# Traffic_Calming                2
# Traffic_Signal                 2
# Turning_Loop                   1
# Sunrise_Sunset                 2
# Civil_Twilight                 2
# Nautical_Twilight              2
# Astronomical_Twilight          2
# dtype: int64

# %%
sev_2[["Civil_Twilight", "Start_Time", "Street", "Weather_Condition"]]
# Out:
#         Civil_Twilight           Start_Time            Street  \
# 1                Night  2016-02-08 05:56:20            I-70 E
# 2                Night  2016-02-08 06:15:39            I-75 S
# 3                Night  2016-02-08 06:51:45            I-77 N
# 5                  Day  2016-02-08 08:16:57    State Route 32
# 6                  Day  2016-02-08 08:15:41            I-75 S
# ...                ...                  ...               ...
# 2845337            Day  2019-08-23 18:03:25      Pomona Fwy E
# 2845338            Day  2019-08-23 19:11:30             I-8 W
# 2845339            Day  2019-08-23 19:00:21  Garden Grove Fwy
# 2845340            Day  2019-08-23 19:00:21   San Diego Fwy S
# 2845341            Day  2019-08-23 18:52:06          CA-210 W
#
#         Weather_Condition
# 1              Light Rain
# 2                Overcast
# 3                Overcast
# 5                Overcast
# 6           Mostly Cloudy
# ...                   ...
# 2845337              Fair
# 2845338              Fair
# 2845339     Partly Cloudy
# 2845340              Fair
# 2845341              Fair
#
# [2532991 rows x 4 columns]

# %% [markdown]
# Snapshot of the values
#
# Sort values with brackets works.
#
# January 2016 to 2022. sev_2.sort_values(["Start_Time"])

# %% [markdown]
# ### Time of day

# %%
type(sev_2["Start_Time"])
# Out:
# pandas.core.series.Series

# %%
sev_2.Civil_Twilight.value_counts()
# Out:
# Day      1711077
# Night     819542
# Name: Civil_Twilight, dtype: int64

# %%
# 2/3 of accidents occur in daylight hours.
sev_2.Civil_Twilight.value_counts(normalize=True)*100
# Out:
# Day      67.614959
# Night    32.385041
# Name: Civil_Twilight, dtype: float64

# %%
sev_2.Start_Time = pd.to_datetime(sev_2.Start_Time)
sev_2.End_Time = pd.to_datetime(sev_2.End_Time)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9448\853571900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sev_2.Start_Time = pd.to_datetime(sev_2.Start_Time)
# C:\Users\User\AppData\Local\Temp\ipykernel_9448\853571900.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sev_2.End_Time = pd.to_datetime(sev_2.End_Time)

# %%
sev_2.dtypes
# Type check after conversion
# Out:
# ID                               object
# Severity                          int64
# Start_Time               datetime64[ns]
# End_Time                 datetime64[ns]
# Start_Lat                       float64
# Start_Lng                       float64
# End_Lat                         float64
# End_Lng                         float64
# Distance(mi)                    float64
# Description                      object
# Number                          float64
# Street                           object
# Side                             object
# City                             object
# County                           object
# State                            object
# Zipcode                          object
# Country                          object
# Timezone                         object
# Airport_Code                     object
# Weather_Timestamp                object
# Temperature(F)                  float64
# Wind_Chill(F)                   float64
# Humidity(%)                     float64
# Pressure(in)                    float64
# Visibility(mi)                  float64
# Wind_Direction                   object
# Wind_Speed(mph)                 float64
# Precipitation(in)               float64
# Weather_Condition                object
# Amenity                            bool
# Bump                               bool
# Crossing                           bool
# Give_Way                           bool
# Junction                           bool
# No_Exit                            bool
# Railway                            bool
# Roundabout                         bool
# Station                            bool
# Stop                               bool
# Traffic_Calming                    bool
# Traffic_Signal                     bool
# Turning_Loop                       bool
# Sunrise_Sunset                   object
# Civil_Twilight                   object
# Nautical_Twilight                object
# Astronomical_Twilight            object
# dtype: object

# %%
sev_2["Start_Hour"] = sev_2.Start_Time.dt.hour
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9448\4171050302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sev_2["Start_Hour"] = sev_2.Start_Time.dt.hour

# %%
sev_2["Start_Hour"].nunique()
# Out:
# 24

# %%
sns.histplot(data=sev_2, x= "Start_Hour")
plt.show()
# sns.histplot(data=sev_2, x= sev_2["Start_Hour"]) Above, forgot ".
# Out:
# <AxesSubplot:xlabel='Start_Hour', ylabel='Count'>

# %%
# Hours with most accidents are in the afternoon, 12-4PM.
    # The other bump is 6-9AM. Probably, 8PM-5AM is quietest.
sev_2["Start_Hour"].value_counts()
# Trying sev_2["Start_Hour"].value_counts().nlargest(3,"Start_Hour")
# Out:
# 17    196443
# 16    194758
# 15    193223
# 14    174399
# 13    151194
# 18    148349
# 12    129529
# 7     119519
# 8     114888
# 19    102907
# 11    100907
# 6      98232
# 9      94932
# 10     91637
# 20     83964
# 21     77792
# 22     72172
# 5      70645
# 23     65848
# 0      60544
# 1      53755
# 2      49635
# 4      45244
# 3      42475
# Name: Start_Hour, dtype: int64

# %%
sev_2["End_Hour"] = sev_2.End_Time.dt.hour
sev_2["Duration"] =sev_2["End_Hour"] - sev_2["Start_Hour"]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9448\1299160197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sev_2["End_Hour"] = sev_2.End_Time.dt.hour
# C:\Users\User\AppData\Local\Temp\ipykernel_9448\1299160197.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sev_2["Duration"] =sev_2["End_Hour"] - sev_2["Start_Hour"]

# %%
sns.boxplot(data=sev_2, x="Duration")
plt.show()
# Out:
# <AxesSubplot:xlabel='Duration'>

# %%
# This is the hours the accident delayed traffic.
    # Where the minus sign is, time might have been >24 hours.
round(sev_2["Duration"].describe(), 2)
# Out:
# count    2532991.00
# mean           0.63
# std            6.49
# min          -23.00
# 25%            1.00
# 50%            2.00
# 75%            3.00
# max           23.00
# Name: Duration, dtype: float64

# %%
# Except for the 31st, the amount of accidents has 0 slope.
sev_2["Start_Day"] = sev_2.Start_Time.dt.day
sns.histplot(data=sev_2, x= "Start_Day")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9448\3441754340.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sev_2["Start_Day"] = sev_2.Start_Time.dt.day
# <AxesSubplot:xlabel='Start_Day', ylabel='Count'>

# %%
# Except for the 31st, the amount of accidents has 0 slope.
sev_2["Start_Dw"] = sev_2.Start_Time.dt.dayofweek
sns.histplot(data=sev_2, x= "Start_Dw")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9448\3546903167.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sev_2["Start_Dw"] = sev_2.Start_Time.dt.dayofweek
# <AxesSubplot:xlabel='Start_Dw', ylabel='Count'>

# %%
# The holiday season may have had an effect on travel
    # from November to January and cold weather in winter.
    # Summer break might have increased the amount of people
    # outside in June.
sev_2["Start_Month"] = sev_2.Start_Time.dt.month
sns.countplot(data=sev_2, x= "Start_Month")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9448\393707045.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sev_2["Start_Month"] = sev_2.Start_Time.dt.month
# <AxesSubplot:xlabel='Start_Month', ylabel='count'>

# %% [markdown]
# ### weather

# %%
A_weather = accidents[['ID','Severity','Temperature(F)' ,'Wind_Chill(F)','Wind_Speed(mph)' ,'Pressure(in)',
                       'Humidity(%)' ,'Precipitation(in)']].copy()
A_weather.head(3)
# Out:
#     ID  Severity  Temperature(F)  Wind_Chill(F)  Wind_Speed(mph)  \
# 0  A-1         3            42.1           36.1             10.4
# 1  A-2         2            36.9            NaN              NaN
# 2  A-3         2            36.0            NaN              NaN
#
#    Pressure(in)  Humidity(%)  Precipitation(in)
# 0         29.76         58.0               0.00
# 1         29.68         91.0               0.02
# 2         29.70         97.0               0.02

# %%
A_weather.corr()['Severity'].sort_values()
# Out:
# Wind_Chill(F)       -0.097459
# Temperature(F)      -0.045335
# Precipitation(in)    0.013845
# Humidity(%)          0.037802
# Pressure(in)         0.043883
# Wind_Speed(mph)      0.048382
# Severity             1.000000
# Name: Severity, dtype: float64

# %%
A_weather['Temperature(F)'].nunique()
# Out:
# 788

# %%
fig, axs = plt.subplots(nrows=2, ncols=2)

axs[0, 0].hist(data=A_weather, x='Temperature(F)' , histtype='bar', facecolor='g',rwidth=0.8)
axs[0, 0].set_title('tem')

axs[0, 1].hist(data=A_weather, x='Pressure(in)',  histtype='bar', facecolor='g',rwidth=0.8)
axs[0, 1].set_title('pressure')

axs[1, 0].hist(data=A_weather, x='Wind_Chill(F)', histtype='bar', rwidth=0.8)
axs[1, 0].set_title('wind')

axs[1, 1].hist(data=A_weather, x='Humidity(%)',  histtype='bar', rwidth=0.8)
axs[1, 1].set_title('humidity')

fig.tight_layout()
plt.show()

# %%
sns.histplot(data=A_weather, x='Wind_Chill(F)', binwidth=8)
plt.show()

# %%
plt.figure(figsize = (7,5))
sns.barplot(x= 'Severity', y ='Wind_Chill(F)', data=A_weather , color="seagreen")
plt.title('relation between severity and temperature ')
plt.xlabel('severity')
plt.ylabel('tem')
plt.show()

# %%
A_road = accidents[['ID','Severity','Crossing','Station','Traffic_Signal','Traffic_Calming',
                   'Stop','Junction','No_Exit','Railway','Turning_Loop']].copy()
A_road.head(3)
# Out:
#     ID  Severity  Crossing  Station  Traffic_Signal  Traffic_Calming   Stop  \
# 0  A-1         3     False    False           False            False  False
# 1  A-2         2     False    False           False            False  False
# 2  A-3         2     False    False           False            False  False
#
#    Junction  No_Exit  Railway  Turning_Loop
# 0     False    False    False         False
# 1     False    False    False         False
# 2      True    False    False         False

# %%
A_road.corr()['Severity'].sort_values()
# Out:
# Crossing          -0.035382
# Station           -0.018017
# Traffic_Signal    -0.012798
# Traffic_Calming   -0.003009
# Stop              -0.002536
# No_Exit           -0.002359
# Railway           -0.001747
# Junction           0.045928
# Severity           1.000000
# Turning_Loop            NaN
# Name: Severity, dtype: float64

# %%
sns.countplot(data=A_road, x='Junction' )
plt.show()

# %% [markdown]
# **state**

# %%
#state wise = sw
sw_counts = accidents.groupby('State')['ID'].count().reset_index()
sw_counts = sw_counts.sort_values(by = "ID",ascending=False)

# %%
f, ax = plt.subplots(figsize=(15, 20))
sns.barplot(y="State", x="ID", data=sw_counts)
plt.show()

# %%
accidents_by_cities = accidents['City'].value_counts()
accidents_by_cities[:5]
# Top 5 cities by number of accidents
# Out:
# Miami          106966
# Los Angeles     68956
# Orlando         54691
# Dallas          41979
# Houston         39448
# Name: City, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,4))
accidents_by_cities[:5].plot(kind='bar')
ax.set(title = 'Top 5 cities By Number of Accidents',
       xlabel = 'Cities',
       ylabel = 'Accidents Count')
plt.show()
#Chart to Visualize Top 5 cities by number of accidents

# %%
fig, axs = plt.subplots(nrows=2, ncols=2)

axs[0, 0].bar(data=A_road, x='Junction',height=6)
axs[0, 0].set_title('tem')

axs[0, 1].bar(data=A_road, x='Crossing',height=6)
axs[0, 1].set_title('pressure')

axs[1, 0].bar(data=A_weather, x='Railway',height=6)
axs[1, 0].set_title('wind')

axs[1, 1].bar(data=A_weather, x='No_Exit',height=6)
axs[1, 1].set_title('humidity')

fig.tight_layout()
plt.show()
